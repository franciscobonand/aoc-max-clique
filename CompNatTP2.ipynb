# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Problema fácil (easy) - 500 nós e 64624 arestas

# %% [markdown]
# Para entendermos o comportamento inicial do algoritmo geramos uma visualização que varia entre as opções de números de formigas (*ants*) e gerações (*gen*), mantendo a taxa de evaporação fixa em *0.05*. Esse valor de evaporação foi escolhido pois sabemos pela literatura do ACO que quando a atualização dos feromônios do melhor caminho é feita de forma elitista o algoritmo tende a gerar melhores resultados com taxas baixas de evaporação, caso contrário o otimizador favorece muito *Explotation* frente à *Exploration*, otimizando apenas no ótimo local e não buscando pelo ótimo global.

# %%
easy_50_50_005 = pd.read_csv('analysis/easy-50-50-0.05',nrows=50)
easy_50_100_005= pd.read_csv('analysis/easy-50-100-0.05', nrows=100)
easy_50_500_005 = pd.read_csv('analysis/easy-50-500-0.05', nrows=500)
easy_100_50_005 = pd.read_csv('analysis/easy-100-50-0.05', nrows=50)
easy_100_100_005 = pd.read_csv('analysis/easy-100-100-0.05', nrows=100)
easy_100_500_005 = pd.read_csv('analysis/easy-100-500-0.05', nrows=500)
easy_200_50_005 = pd.read_csv('analysis/easy-200-50-0.05', nrows=50)
easy_200_100_005 = pd.read_csv('analysis/easy-200-100-0.05', nrows=100)
easy_200_500_005 = pd.read_csv('analysis/easy-200-500-0.05', nrows=500)
easy_500_50_005 = pd.read_csv('analysis/easy-500-50-0.05', nrows=50)
easy_500_100_005 = pd.read_csv('analysis/easy-500-100-0.05', nrows=100)
easy_500_500_005 = pd.read_csv('analysis/easy-500-500-0.05', nrows=500)

# %% [markdown]
# ## Max Clique por geração e quantidade de formigas

# %%
min_tour_by_gen = pd.DataFrame({
    "Ants: 50 & Gen: 50": easy_50_50_005["best"],
    "Ants: 50 & Gen: 100": easy_50_100_005["best"],
    "Ants: 50 & Gen: 500": easy_50_500_005["best"],
    "Ants: 100 & Gen: 50": easy_100_500_005["best"],
    "Ants: 100 & Gen: 100": easy_100_100_005["best"],
    "Ants: 100 & Gen: 500": easy_100_500_005["best"],
    "Ants: 200 & Gen: 50": easy_200_500_005["best"],
    "Ants: 200 & Gen: 100": easy_200_100_005["best"],
    "Ants: 200 & Gen: 500": easy_200_500_005["best"],
    "Ants: 500 & Gen: 50": easy_500_50_005["best"],
    "Ants: 500 & Gen: 100": easy_500_100_005["best"],
    "Ants: 500 & Gen: 500": easy_500_500_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=min_tour_by_gen[[
    "Ants: 50 & Gen: 50",
    "Ants: 50 & Gen: 100",
    "Ants: 50 & Gen: 500",
    "Ants: 100 & Gen: 50",
    "Ants: 100 & Gen: 100",
    "Ants: 100 & Gen: 500",
    "Ants: 200 & Gen: 50",
    "Ants: 200 & Gen: 100",
    "Ants: 200 & Gen: 500",
    "Ants: 500 & Gen: 50",
    "Ants: 500 & Gen: 100",
    "Ants: 500 & Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração e qnte de formigas")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Esse gráfico não revela uma hierarquia clara dos efeitos de cada parâmetro sobre o valor máximo de clique encontrado. Podemos observar apenas que tanto para *ants* quanto para *gen* quanto maior for o valor assumido pelo parâmetro, melhor a performance do ACO. Portanto realizaremos análises para esses parâmetros separadamente fixando um deles alternadamente. Os valores serão fixados em 200 visto que, a partir desse limiar, a melhoria dos melhores resultados é pouco significativa.

# %% [markdown]
# ## Max Clique por quantidade de formigas para 200 gerações

# %%
easy_20_200_005 = pd.read_csv('analysis/easy-20-200-0.05',nrows=200)
easy_50_200_005 = pd.read_csv('analysis/easy-50-200-0.05', nrows=200)
easy_100_200_005 = pd.read_csv('analysis/easy-100-200-0.05', nrows=200)
easy_200_200_005= pd.read_csv('analysis/easy-200-200-0.05', nrows=200)
easy_500_200_005 = pd.read_csv('analysis/easy-500-200-0.05', nrows=200)
easy_max_by_ants = pd.DataFrame({
   "Ants: 20" : easy_20_200_005["best"],
   "Ants: 50" : easy_50_200_005["best"],
   "Ants: 100" : easy_100_200_005["best"],
   "Ants: 200" : easy_200_200_005["best"],
   "Ants: 500" : easy_500_200_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
   "Ants: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por gerações para 200 formigas

# %%
easy_200_20_005 = pd.read_csv('analysis/easy-200-20-0.05',nrows=20)
easy_200_50_005 = pd.read_csv('analysis/easy-200-50-0.05', nrows=50)
easy_200_100_005 = pd.read_csv('analysis/easy-200-100-0.05', nrows=100)
easy_200_200_005= pd.read_csv('analysis/easy-200-200-0.05', nrows=200)
easy_200_500_005 = pd.read_csv('analysis/easy-200-500-0.05', nrows=500)
easy_max_by_gen = pd.DataFrame({
   "Gen: 20" : easy_200_20_005["best"],
   "Gen: 50" : easy_200_50_005["best"],
   "Gen: 100" : easy_200_100_005["best"],
   "Gen: 200" : easy_200_200_005["best"],
   "Gen: 500" : easy_200_500_005["best"],

  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Ambos os gráficos acima validam a análise feita anteriormente, o ACO apresenta resultados melhores quanto maior o número de *ants* e *gen*. Com isso, o valor 500 para cada um desses parâmetros foi o escolhido.
#
# A seguir analisaremos como a variação da taxa de evaporação afeta os resultados do ACO.

# %% [markdown]
# ## Max Clique por taxa de evaporação para 200 gerações e 200 formigas

# %%
easy_200_200_005 = pd.read_csv('analysis/easy-200-200-0.05',nrows=200)
easy_200_200_010 = pd.read_csv('analysis/easy-200-200-0.10', nrows=200)
easy_200_200_020 = pd.read_csv('analysis/easy-200-200-0.20', nrows=200)
easy_200_200_030 = pd.read_csv('analysis/easy-200-200-0.30', nrows=200)
easy_200_200_050 = pd.read_csv('analysis/easy-200-200-0.50', nrows=200)
easy_max_by_evap = pd.DataFrame({
   "Evaporation Rate: 0.05" : easy_200_200_005["best"],
   "Evaporation Rate: 0.10" : easy_200_200_010["best"],
   "Evaporation Rate: 0.20" : easy_200_200_020["best"],
   "Evaporation Rate: 0.30" : easy_200_200_030["best"],
   "Evaporation Rate: 0.50" : easy_200_200_050["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_evap[[
   "Evaporation Rate: 0.05",
   "Evaporation Rate: 0.10",
   "Evaporation Rate: 0.20",
   "Evaporation Rate: 0.30",
   "Evaporation Rate: 0.50",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por taxa de evaporação")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Esse gráfico mostra um comportamento erratico, visto que múltiplos valores diferentes de evaporação geraram o mesmo resultado. Contudo a diferença entre os valores de max clique encontrados é baixa o suficiente que podemos assumir que variabilidade estocástica está afetando essa análise. Para validar essa suposição analisaremos a variação gerada pela taxa de evaporação com mais formigas e gerações:

# %%
easy_500_500_005 = pd.read_csv('analysis/easy-500-500-0.05',nrows=500)
easy_500_500_010 = pd.read_csv('analysis/easy-500-500-0.10', nrows=500)
easy_500_500_020 = pd.read_csv('analysis/easy-500-500-0.20', nrows=500)
easy_500_500_030 = pd.read_csv('analysis/easy-500-500-0.30', nrows=500)
easy_max_by_evap2 = pd.DataFrame({
   "Evaporation Rate: 0.05" : easy_500_500_005["best"],
   "Evaporation Rate: 0.10" : easy_500_500_010["best"],
   "Evaporation Rate: 0.20" : easy_500_500_020["best"],
   "Evaporation Rate: 0.30" : easy_500_500_030["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_evap2[[
   "Evaporation Rate: 0.05",
   "Evaporation Rate: 0.10",
   "Evaporation Rate: 0.20",
   "Evaporation Rate: 0.30",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por taxa de evaporação")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Observamos que, por uma margem baixa, o valor de evaporação *0.3* se destaca como superior aos demais. Portanto usaremos esse valor para análise dos dois parametros restantes.

# %% [markdown]
# ## Max Clique por quantidade de formigas para 500 gerações e taxa de evaporação de 30%

# %%
easy_20_200_030 = pd.read_csv('analysis/easy-20-500-0.30',nrows=200)
easy_50_200_030 = pd.read_csv('analysis/easy-50-500-0.30', nrows=200)
easy_100_200_030 = pd.read_csv('analysis/easy-100-500-0.30', nrows=200)
easy_200_200_030= pd.read_csv('analysis/easy-200-500-0.30', nrows=200)
easy_500_200_030 = pd.read_csv('analysis/easy-500-500-0.30', nrows=200)

easy_max_by_ants = pd.DataFrame({
   "Ants: 20" : easy_20_200_030["best"],
   "Ants: 50" : easy_50_200_030["best"],
   "Ants: 100" : easy_100_200_030["best"],
   "Ants: 200" : easy_200_200_030["best"],
   "Ants: 500" : easy_500_200_030["best"],

  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
   "Ants: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique média por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por geração com 500 formigas e taxa de evaporação de 30%

# %%
easy_200_20_030 = pd.read_csv('analysis/easy-500-20-0.30',nrows=20)
easy_200_50_030 = pd.read_csv('analysis/easy-500-50-0.30', nrows=50)
easy_200_100_030 = pd.read_csv('analysis/easy-500-100-0.30', nrows=100)
easy_200_200_030= pd.read_csv('analysis/easy-500-200-0.30', nrows=200)
easy_200_500_030 = pd.read_csv('analysis/easy-500-500-0.30', nrows=500)

easy_max_by_gen = pd.DataFrame({
   "Gen: 20" : easy_200_20_030["best"],
   "Gen: 50" : easy_200_50_030["best"],
   "Gen: 100" : easy_200_100_030["best"],
   "Gen: 200" : easy_200_200_030["best"],
   "Gen: 500" : easy_200_500_030["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Variação dos resultados por indivíduos da população

# %%
easy_max_by_gen = pd.DataFrame({
   "Max" : easy_200_500_030["best"],
   "Mean" : easy_200_500_030["mean"],
   "Min" : easy_200_500_030["worst"]
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=easy_max_by_gen[[
  "Max",
  "Mean",
  "Min"
]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Variação das cliques por indivíduos da população")
plt.xlim([0, 500])
plt.show()

# %% [markdown]
# Comparando os valores máximos, médios e mínimos não observamos convergência desses valores para o ótimo, isso implica que o algoritmo implementado não sofreu overfit por excesso de exploitation. Podemos assumir que, apesar da melhoria nos resultados máximos ocorrer continuamente, não deixa de ocorrer exploração do grafo em busca de novas soluções.

# %% [markdown]
# # Problema difícil (hard) - 700 nós e 121728 arestas

# %%
hard_50_50_005 = pd.read_csv('analysis/hard-50-50-0.05',nrows=50)
hard_50_100_005= pd.read_csv('analysis/hard-50-100-0.05', nrows=100)
hard_50_500_005 = pd.read_csv('analysis/hard-50-500-0.05', nrows=500)
hard_100_50_005 = pd.read_csv('analysis/hard-100-50-0.05', nrows=50)
hard_100_100_005 = pd.read_csv('analysis/hard-100-100-0.05', nrows=100)
hard_100_500_005 = pd.read_csv('analysis/hard-100-500-0.05', nrows=500)
hard_200_50_005 = pd.read_csv('analysis/hard-200-50-0.05', nrows=50)
hard_200_100_005 = pd.read_csv('analysis/hard-200-100-0.05', nrows=100)
hard_200_500_005 = pd.read_csv('analysis/hard-200-500-0.05', nrows=500)
hard_500_50_005 = pd.read_csv('analysis/hard-500-50-0.05', nrows=50)
hard_500_100_005 = pd.read_csv('analysis/hard-500-100-0.05', nrows=100)
hard_500_500_005 = pd.read_csv('analysis/hard-500-500-0.05', nrows=500)

# %% [markdown]
# Para entendermos o comportamento inicial do algoritmo geramos uma visualização que varia entre as opções de números de formigas (*ants*) e gerações (*gen*), mantendo a taxa de evaporação fixa em *0.05*. Esse valor de evaporação foi escolhido pois sabemos pela literatura do ACO que quando a atualização dos feromônios do melhor caminho é feita de forma elitista o algoritmo tende a gerar melhores resultados com taxas baixas de evaporação, caso contrário o otimizador favorece muito *Explotation* frente à *Exploration*, otimizando apenas no ótimo local e não buscando pelo ótimo global.

# %% [markdown]
# ## Max Clique por geração e quantidade de formigas

# %%
min_tour_by_gen = pd.DataFrame({
    "Ants: 50 & Gen: 50": hard_50_50_005["best"],
    "Ants: 50 & Gen: 100": hard_50_100_005["best"],
    "Ants: 50 & Gen: 500": hard_50_500_005["best"],
    "Ants: 100 & Gen: 50": hard_100_500_005["best"],
    "Ants: 100 & Gen: 100": hard_100_100_005["best"],
    "Ants: 100 & Gen: 500": hard_100_500_005["best"],
    "Ants: 200 & Gen: 50": hard_200_500_005["best"],
    "Ants: 200 & Gen: 100": hard_200_100_005["best"],
    "Ants: 200 & Gen: 500": hard_200_500_005["best"],
    "Ants: 500 & Gen: 50": hard_500_50_005["best"],
    "Ants: 500 & Gen: 100": hard_500_100_005["best"],
    "Ants: 500 & Gen: 500": hard_500_500_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=min_tour_by_gen[[
    "Ants: 50 & Gen: 50",
    "Ants: 50 & Gen: 100",
    "Ants: 50 & Gen: 500",
    "Ants: 100 & Gen: 50",
    "Ants: 100 & Gen: 100",
    "Ants: 100 & Gen: 500",
    "Ants: 200 & Gen: 50",
    "Ants: 200 & Gen: 100",
    "Ants: 200 & Gen: 500",
    "Ants: 500 & Gen: 50",
    "Ants: 500 & Gen: 100",
    "Ants: 500 & Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração e qnte de formigas")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Esse gráfico não revela uma hierarquia clara dos efeitos de cada parâmetro sobre o valor máximo de clique encontrado. Podemos observar apenas que tanto para *ants* quanto para *gen* quanto maior for o valor assumido pelo parâmetro, melhor a performance do ACO. Portanto realizaremos análises para esses parâmetros separadamente fixando um deles alternadamente. Os valores serão fixados em 200 visto que, a partir desse limiar, a melhoria dos melhores resultados é pouco significativa.

# %% [markdown]
# ## Max Clique por quantidade de formigas para 200 gerações

# %%
hard_20_200_005 = pd.read_csv('analysis/hard-20-200-0.05',nrows=200)
hard_50_200_005 = pd.read_csv('analysis/hard-50-200-0.05', nrows=200)
hard_100_200_005 = pd.read_csv('analysis/hard-100-200-0.05', nrows=200)
hard_200_200_005= pd.read_csv('analysis/hard-200-200-0.05', nrows=200)
hard_500_200_005 = pd.read_csv('analysis/hard-500-200-0.05', nrows=200)
hard_max_by_ants = pd.DataFrame({
   "Ants: 20" : hard_20_200_005["best"],
   "Ants: 50" : hard_50_200_005["best"],
   "Ants: 100" : hard_100_200_005["best"],
   "Ants: 200" : hard_200_200_005["best"],
   "Ants: 500" : hard_500_200_005["best"],

  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
   "Ants: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por gerações para 200 formigas

# %%
hard_200_20_005 = pd.read_csv('analysis/hard-200-20-0.05',nrows=20)
hard_200_50_005 = pd.read_csv('analysis/hard-200-50-0.05', nrows=50)
hard_200_100_005 = pd.read_csv('analysis/hard-200-100-0.05', nrows=100)
hard_200_200_005= pd.read_csv('analysis/hard-200-200-0.05', nrows=200)
hard_200_500_005 = pd.read_csv('analysis/hard-200-500-0.05', nrows=500)
hard_max_by_gen = pd.DataFrame({
   "Gen: 20" : hard_200_20_005["best"],
   "Gen: 50" : hard_200_50_005["best"],
   "Gen: 100" : hard_200_100_005["best"],
   "Gen: 200" : hard_200_200_005["best"],
   "Gen: 500" : hard_200_500_005["best"],

  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Ambos os gráficos acima são contrários à análise feita anteriormente, visto que o ACO apresenta resultados melhores quando o número de *ants* e *gen* é 200, e não 500. Com isso, seguiremos com esse melhor valor para esses parâmetros.
#
# A seguir analisaremos como a variação da taxa de evaporação afeta os resultados do ACO.

# %% [markdown]
# ## Max Clique por taxa de evaporação para 200 gerações e 200 formigas

# %%
hard_200_200_005 = pd.read_csv('analysis/hard-200-200-0.05',nrows=200)
hard_200_200_010 = pd.read_csv('analysis/hard-200-200-0.10', nrows=200)
hard_200_200_020 = pd.read_csv('analysis/hard-200-200-0.20', nrows=200)
hard_200_200_030 = pd.read_csv('analysis/hard-200-200-0.30', nrows=200)
hard_200_200_050 = pd.read_csv('analysis/hard-200-200-0.50', nrows=200)
hard_max_by_evap = pd.DataFrame({
   "Evaporation Rate: 0.05" : hard_200_200_005["best"],
   "Evaporation Rate: 0.10" : hard_200_200_010["best"],
   "Evaporation Rate: 0.20" : hard_200_200_020["best"],
   "Evaporation Rate: 0.30" : hard_200_200_030["best"],
   "Evaporation Rate: 0.50" : hard_200_200_050["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_evap[[
   "Evaporation Rate: 0.05",
   "Evaporation Rate: 0.10",
   "Evaporation Rate: 0.20",
   "Evaporation Rate: 0.30",
   "Evaporation Rate: 0.50",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por taxa de evaporação")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Observamos que, conforme o esperado, o valor de evaporação *0.05* se destaca como superior aos demais. Portanto usaremos esse valor para análise dos dois parametros restantes.

# %% [markdown]
# ## Max Clique por quantidade de formigas para 200 gerações e taxa de evaporação de 5%

# %%
hard_20_200_010 = pd.read_csv('analysis/hard-20-200-0.05',nrows=200)
hard_50_200_010 = pd.read_csv('analysis/hard-50-200-0.05', nrows=200)
hard_100_200_010 = pd.read_csv('analysis/hard-100-200-0.05', nrows=200)
hard_200_200_010= pd.read_csv('analysis/hard-200-200-0.05', nrows=200)
hard_500_200_010 = pd.read_csv('analysis/hard-500-200-0.05', nrows=200)

hard_max_by_ants = pd.DataFrame({
   "Ants: 20" : hard_20_200_010["best"],
   "Ants: 50" : hard_50_200_010["best"],
   "Ants: 100" : hard_100_200_010["best"],
   "Ants: 200" : hard_200_200_010["best"],
   "Ants: 500" : hard_500_200_010["best"],

  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
   "Ants: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique média por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por geração com 200 formigas e taxa de evaporação de 5%

# %%
hard_200_20_010 = pd.read_csv('analysis/hard-200-20-0.05',nrows=20)
hard_200_50_010 = pd.read_csv('analysis/hard-200-50-0.05', nrows=50)
hard_200_100_010 = pd.read_csv('analysis/hard-200-100-0.05', nrows=100)
hard_200_200_010= pd.read_csv('analysis/hard-200-200-0.05', nrows=200)
hard_200_500_010 = pd.read_csv('analysis/hard-200-500-0.05', nrows=500)

hard_max_by_gen = pd.DataFrame({
   "Gen: 20" : hard_200_20_010["best"],
   "Gen: 50" : hard_200_50_010["best"],
   "Gen: 100" : hard_200_100_010["best"],
   "Gen: 200" : hard_200_200_010["best"],
   "Gen: 500" : hard_200_500_010["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Variação dos resultados por indivíduos da população

# %%
hard_max_by_gen = pd.DataFrame({
   "Max" : hard_200_200_010["best"],
   "Mean" : hard_200_200_010["mean"],
   "Min" : hard_200_200_010["worst"]
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=hard_max_by_gen[[
  "Max",
  "Mean",
  "Min"
]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Variação das cliques por indivíduos da população")
plt.xlim([0, 200])
plt.show()

# %% [markdown]
# Para este problema, pode-se chegar na mesma conclusão que o anterior: comparando os valores máximos, médios e mínimos não observamos convergência desses valores para o ótimo, isso implica que o algoritmo implementado não sofreu overfit por excesso de exploitation. Podemos assumir que, apesar da melhoria nos resultados máximos ocorrer continuamente, não deixa de ocorrer exploração do grafo em busca de novas soluções.

# %% [markdown]
# # Problema mais difícil (harder) - 800 nós e 207643 arestas

# %%
harder_50_50_005 = pd.read_csv('analysis/harder-50-50-0.05',nrows=50)
harder_50_100_005= pd.read_csv('analysis/harder-50-100-0.05', nrows=100)
harder_50_500_005 = pd.read_csv('analysis/harder-50-500-0.05', nrows=500)
harder_100_50_005 = pd.read_csv('analysis/harder-100-50-0.05', nrows=50)
harder_100_100_005 = pd.read_csv('analysis/harder-100-100-0.05', nrows=100)
harder_100_500_005 = pd.read_csv('analysis/harder-100-500-0.05', nrows=500)
harder_200_50_005 = pd.read_csv('analysis/harder-200-50-0.05', nrows=50)
harder_200_100_005 = pd.read_csv('analysis/harder-200-100-0.05', nrows=100)
harder_200_500_005 = pd.read_csv('analysis/harder-200-500-0.05', nrows=500)
harder_500_500_005 = pd.read_csv('analysis/harder-500-500-0.05', nrows=500)

# %% [markdown]
# Para entendermos o comportamento inicial do algoritmo geramos uma visualização que varia entre as opções de números de formigas (*ants*) e gerações (*gen*), mantendo a taxa de evaporação fixa em *0.05*. Esse valor de evaporação foi escolhido pois sabemos pela literatura do ACO que quando a atualização dos feromônios do melhor caminho é feita de forma elitista o algoritmo tende a gerar melhores resultados com taxas baixas de evaporação, caso contrário o otimizador favorece muito *Explotation* frente à *Exploration*, otimizando apenas no ótimo local e não buscando pelo ótimo global.

# %% [markdown]
# ## Max Clique por geração e quantidade de formigas

# %%
min_tour_by_gen = pd.DataFrame({
    "Ants: 50 & Gen: 50": harder_50_50_005["best"],
    "Ants: 50 & Gen: 100": harder_50_100_005["best"],
    "Ants: 50 & Gen: 500": harder_50_500_005["best"],
    "Ants: 100 & Gen: 50": harder_100_500_005["best"],
    "Ants: 100 & Gen: 100": harder_100_100_005["best"],
    "Ants: 100 & Gen: 500": harder_100_500_005["best"],
    "Ants: 200 & Gen: 50": harder_200_500_005["best"],
    "Ants: 200 & Gen: 100": harder_200_100_005["best"],
    "Ants: 200 & Gen: 500": harder_200_500_005["best"],
    "Ants: 500 & Gen: 500": harder_500_500_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=min_tour_by_gen[[
    "Ants: 50 & Gen: 50",
    "Ants: 50 & Gen: 100",
    "Ants: 50 & Gen: 500",
    "Ants: 100 & Gen: 50",
    "Ants: 100 & Gen: 100",
    "Ants: 100 & Gen: 500",
    "Ants: 200 & Gen: 50",
    "Ants: 200 & Gen: 100",
    "Ants: 200 & Gen: 500",
    "Ants: 500 & Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração e qnte de formigas")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Esse gráfico não revela uma hierarquia clara dos efeitos de cada parâmetro sobre o valor máximo de clique encontrado. Podemos observar apenas que tanto para *ants* quanto para *gen* quanto maior for o valor assumido pelo parâmetro, melhor a performance do ACO. Portanto realizaremos análises para esses parâmetros separadamente fixando um deles alternadamente. Os valores serão fixados em 200 visto que, a partir desse limiar, a melhoria dos melhores resultados é pouco significativa.

# %% [markdown]
# ## Max Clique por quantidade de formigas para 200 gerações

# %%
harder_20_200_005 = pd.read_csv('analysis/harder-20-200-0.05',nrows=200)
harder_50_200_005 = pd.read_csv('analysis/harder-50-200-0.05', nrows=200)
harder_100_200_005 = pd.read_csv('analysis/harder-100-200-0.05', nrows=200)
harder_200_200_005= pd.read_csv('analysis/harder-200-200-0.05', nrows=200)
harder_max_by_ants = pd.DataFrame({
   "Ants: 20" : harder_20_200_005["best"],
   "Ants: 50" : harder_50_200_005["best"],
   "Ants: 100" : harder_100_200_005["best"],
   "Ants: 200" : harder_200_200_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por gerações para 200 formigas

# %%
harder_200_20_005 = pd.read_csv('analysis/harder-200-20-0.05',nrows=20)
harder_200_50_005 = pd.read_csv('analysis/harder-200-50-0.05', nrows=50)
harder_200_100_005 = pd.read_csv('analysis/harder-200-100-0.05', nrows=100)
harder_200_200_005= pd.read_csv('analysis/harder-200-200-0.05', nrows=200)
harder_200_500_005 = pd.read_csv('analysis/harder-200-500-0.05', nrows=500)
harder_max_by_gen = pd.DataFrame({
   "Gen: 20" : harder_200_20_005["best"],
   "Gen: 50" : harder_200_50_005["best"],
   "Gen: 100" : harder_200_100_005["best"],
   "Gen: 200" : harder_200_200_005["best"],
   "Gen: 500" : harder_200_500_005["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Ambos os gráficos acima são contrários à análise feita anteriormente, visto que o ACO apresenta resultados melhores quando o número de *ants* é 200 e *gen* é 500, e não 500x500. Com isso, seguiremos com esses melhores valores para esses parâmetros.
#
# A seguir analisaremos como a variação da taxa de evaporação afeta os resultados do ACO.

# %% [markdown]
# ## Max Clique por taxa de evaporação para 500 gerações e 200 formigas

# %%
harder_200_200_005 = pd.read_csv('analysis/harder-200-500-0.05',nrows=200)
harder_200_200_010 = pd.read_csv('analysis/harder-200-500-0.10', nrows=200)
harder_200_200_020 = pd.read_csv('analysis/harder-200-500-0.20', nrows=200)
harder_200_200_030 = pd.read_csv('analysis/harder-200-500-0.30', nrows=200)
harder_max_by_evap = pd.DataFrame({
   "Evaporation Rate: 0.05" : harder_200_200_005["best"],
   "Evaporation Rate: 0.10" : harder_200_200_010["best"],
   "Evaporation Rate: 0.20" : harder_200_200_020["best"],
   "Evaporation Rate: 0.30" : harder_200_200_030["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_evap[[
   "Evaporation Rate: 0.05",
   "Evaporation Rate: 0.10",
   "Evaporation Rate: 0.20",
   "Evaporation Rate: 0.30",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por taxa de evaporação")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# Observamos que, conforme o esperado, o valor de evaporação *0.05* se destaca como superior aos demais, com exceção de *0.3* que parece ter performado igualmente bem. Todavia, usaremos o valor *0.05* para análise dos dois parametros restantes.
# **Obs: não foi possível realizar esse experimento com taxa de evaporação de 0.5, devido ao tempo de execução.**

# %% [markdown]
# ## Max Clique por quantidade de formigas para 500 gerações e taxa de evaporação de 5%

# %%
harder_20_200_010 = pd.read_csv('analysis/harder-20-500-0.05',nrows=200)
harder_50_200_010 = pd.read_csv('analysis/harder-50-500-0.05', nrows=200)
harder_100_200_010 = pd.read_csv('analysis/harder-100-500-0.05', nrows=200)
harder_200_200_010= pd.read_csv('analysis/harder-200-500-0.05', nrows=200)

harder_max_by_ants = pd.DataFrame({
   "Ants: 20" : harder_20_200_010["best"],
   "Ants: 50" : harder_50_200_010["best"],
   "Ants: 100" : harder_100_200_010["best"],
   "Ants: 200" : harder_200_200_010["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_ants[[
   "Ants: 20",
   "Ants: 50",
   "Ants: 100",
   "Ants: 200",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique média por quantidade de formigas")
plt.xlim([0, 200])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Max Clique por geração com 200 formigas e taxa de evaporação de 5%

# %%
harder_200_20_010 = pd.read_csv('analysis/harder-200-20-0.05',nrows=20)
harder_200_50_010 = pd.read_csv('analysis/harder-200-50-0.05', nrows=50)
harder_200_100_010 = pd.read_csv('analysis/harder-200-100-0.05', nrows=100)
harder_200_200_010= pd.read_csv('analysis/harder-200-200-0.05', nrows=200)
harder_200_500_010 = pd.read_csv('analysis/harder-200-500-0.05', nrows=500)

harder_max_by_gen = pd.DataFrame({
   "Gen: 20" : harder_200_20_010["best"],
   "Gen: 50" : harder_200_50_010["best"],
   "Gen: 100" : harder_200_100_010["best"],
   "Gen: 200" : harder_200_200_010["best"],
   "Gen: 500" : harder_200_500_010["best"],
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_gen[[
   "Gen: 20",
   "Gen: 50",
   "Gen: 100",
   "Gen: 200",
   "Gen: 500",
    ]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Max Clique dos melhores indivíduos por geração")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# ## Variação dos resultados por indivíduos da população

# %%
harder_max_by_gen = pd.DataFrame({
   "Max" : harder_200_500_010["best"],
   "Mean" : harder_200_500_010["mean"],
   "Min" : harder_200_500_010["worst"]
  })

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=harder_max_by_gen[[
  "Max",
  "Mean",
  "Min"
]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Variação das cliques por indivíduos da população")
plt.xlim([0, 500])
plt.show()

# %% [markdown]
# Para este problema, pode-se chegar na mesma conclusão que os dois anteriores: comparando os valores máximos, médios e mínimos não observamos convergência desses valores para o ótimo, isso implica que o algoritmo implementado não sofreu overfit por excesso de exploitation. Podemos assumir que, apesar da melhoria nos resultados máximos ocorrer continuamente, não deixa de ocorrer exploração do grafo em busca de novas soluções.

# %% [markdown]
# # Diferença entre Max Clique encontrado e Max Clique real para todos os datasets

# %%
easy_500_500_010 = pd.read_csv('analysis/easy-500-500-0.10', nrows=500)
hard_500_500_010 = pd.read_csv('analysis/hard-500-500-0.10', nrows=500)
harder_500_500_010 = pd.read_csv('analysis/harder-500-500-0.10', nrows=500)

max_by_file = pd.DataFrame({
   "Easy" : easy_500_500_010["best"],
   "Hard" : hard_500_500_010["best"],
   "Harder" : harder_500_500_010["best"],
})

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=max_by_file[[
   "Easy",
   "Hard",
   "Harder"
]])
plt.xlabel("Gerações")
plt.ylabel("Max Clique")
plt.title("Distância entre o Max Clique encontrado e o real para os três datasets")
plt.xlim([0, 500])
plt.axhline(13, color="red")
plt.axhline(26, color="red")
plt.axhline(44, color="red")
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# # Desvio padrão

# %% [markdown]
# Geramos valores de desvio padrão com relação ao melhor Max Clique gerado por geração para todas as 30 repetições realizadas para cada um dos experimentos.
# É possível observar que, para os problemas *easy* e *harder* os valores de desvio padrão encontrados são bem baixos (em torno de 1), enquando para o problema *hard* esse valor foi um pouco maior, por volta de 3.5, porém ainda relativamente baixo.
# Com isso podemos concluir que repetir a execução dos experimentos 30 vezes nos garantiu confiabilidade estatística.

# %%
easy_500_500_010 = pd.read_csv('analysis/easy-500-500-0.30', nrows=500)
hard_500_500_010 = pd.read_csv('analysis/hard-200-200-0.05', nrows=500)
harder_500_500_010 = pd.read_csv('analysis/harder-200-500-0.05', nrows=500)

max_by_file = pd.DataFrame({
   "Easy" : easy_500_500_010["sdev"],
   "Hard" : hard_500_500_010["sdev"],
   "Harder" : harder_500_500_010["sdev"],
})

sns.set(rc={'figure.figsize':(15, 10)})
sns.lineplot(data=max_by_file[[
   "Easy",
   "Hard",
   "Harder"
]])
plt.xlabel("Gerações")
plt.ylabel("Desvio Padrão")
plt.title("Desvio Padrão por gerações usando os melhores parâmetros encontrados")
plt.xlim([0, 500])
# plt.ylim([6.0, 7.0])
plt.show()

# %% [markdown]
# # Conclusão
#
# Testamos o algoritmo implementado exaustivamente, ao analisar os dados obtidos observamos que cada problema avaliado se comporta melhor com um conjunto de parâmetros distinto:
#
# ||  No Formigas |  No Geraçoes |  Evaporaçao |
# | -------- | -------------- | -------------- | ------------- |
# | Easy   | 500          | 500          | 0.3         |
# | Hard   | 200          | 200          | 0.05        |
# | Harder | 200          | 500          | 0.05        |
#
# Para todos os três problemas de avaliação observamos que quanto maior o valor dos parâmetros ants e gen melhor são os resultados, porém a melhoria dos resultados decai quando esses valores passam de 200. A execução de experimentos com mais de 500 formigas ou gerações é inviável visto que, nos problemas difíceis, cada execução demorou cerca de cinco horas para esses valores. Apesar disso, é seguro dizer que o aumento além do valor desses parâmetros pode gerar melhoria nos resultados, a depender de variabilidade estocástica, contudo essas melhorias seriam progressivamente menos significativas.
#
# No que diz respeito à taxa de evaporação, como discutido anteriormente, observamos o que era esperado nos problemas difíceis. Para um ACO que atualiza os melhores caminhos de forma elitista é benéfico usar uma taxa de evaporação mais baixa para favorecer a exploração mais abrangente do espaço de soluções. Já para o problema fácil observamos taxas ligeiramente maiores de evaporação gerando resultados superiores. Isso se deve à capacidade do algoritmo implementado de encontrar o máximo global, provavelmente devido ao número reduzido de nós no gráfico, visto que com volume de formigas superior ao de nós a exploração é favorecida. Sendo assim, para esse problema, o aumento da *exploitation* por meio do aumento da taxa de evaporação favorece convergência mais rápida para o ótimo global.
